# %%
from dataProcess.load_data import load_all_data
from dataProcess.visualize_data import analyze_ticket_data
from dataProcess.forecast_tickets import forecast_tickets

ticket_df, rientri_df, spedizioni_df, materiale_clienti_df = load_all_data()

# Display the first few rows of each DataFrame for verification
print("Ticket DataFrame:")
print(ticket_df.head())

print("\nRientri DataFrame:")
print(rientri_df.head())

print("\nSpedizioni DataFrame:")
print(spedizioni_df.head())
# Out:
# Connected to the database
# Connection closed
# Connected to the database
# Connection closed
# Connected to the database
# Connection closed
# Connected to the database
# Connection closed
# Loaded  12109  tickets into df
# Loaded  352  returns into df
# Loaded  3423  shipments into df
# Loaded  6  clients into df
# Ticket DataFrame:
#    id_ticket  id_operatore  id_cliente              data_apertura  \
# 0       1961           4.0      1666.0 2017-09-20 16:55:00.843757
# 1       1948           4.0         NaN 2017-09-19 09:18:27.451619
# 2       2188           4.0      1051.0 2017-11-17 16:57:10.748252
# 3       1956           4.0      1842.0 2017-09-20 11:03:15.915667
# 4       2320          11.0         NaN 2018-01-22 11:28:40.282061
#
#                data_modifica  id_istanza  ticket_ext  id_stato  \
# 0 2017-09-20 16:56:18.386715      1661.0  KXL-27-ZUQ  CHIUSURA
# 1 2017-09-22 11:13:41.226613      1932.0  UZR-34-CXZ  CHIUSURA
# 2 2017-11-17 16:59:10.589520      2211.0  DJR-42-VYS  CHIUSURA
# 3 2017-09-22 16:13:35.806927      1885.0  DVX-59-VMN  CHIUSURA
# 4 2018-01-22 12:05:14.621949      2799.0  GYZ-79-NTR  CHIUSURA
#
#     data_segnalazione rientro tipo_problema terze_parti spedizione intervento  \
# 0 2017-09-20 16:25:00    None          None        None       None       None
# 1 2017-09-19 08:50:00    None          None        None       None       None
# 2 2017-11-17 16:45:00    None          None        None       None       None
# 3 2017-09-20 09:30:00    None          None        None       None       None
# 4 2018-01-22 09:30:00    None          None        None       None       None
#
#   data_intervento_tkt operatore_nome operatore_cognome cliente_nome  \
# 0                 NaT          Maria         Cuscianna         None
# 1                 NaT          Maria         Cuscianna         None
# 2                 NaT          Maria         Cuscianna         None
# 3                 NaT          Maria         Cuscianna         None
# 4                 NaT       Federico             Raiti         None
#
#   gruppo_descrizione
# 0      Area Supporto
# 1      Area Supporto
# 2      Area Supporto
# 3      Area Supporto
# 4    Area Tecnologia
#
# Rientri DataFrame:
#    id_ticket  id_rientro           data_inserimento  \
# 0     3426.0        1014 2018-11-07 12:22:16.713051
# 1     2756.0        1001 2018-12-06 11:00:17.108274
# 2     2756.0        1020 2018-11-26 08:17:26.826584
# 3     3763.0        1036 2019-01-22 16:16:55.716510
# 4     3600.0        1026 2018-12-19 15:22:26.095707
#
#                                              rientro  id_operatore  \
# 0  Rientro da organizzare,\nContatto: 0419 656 32...             6
# 1                                      prova rientro             6
# 2                      RICHIESTO IL 06/12/2018 11:00             6
# 3  Fa rientaare il monitor touch hannspree non ut...             4
# 4  Stampante KR203, rientro da organizzare.<br />...            12
#
#   operatore_nome operatore_cognome
# 0         Matteo          De Ponti
# 1         Matteo          De Ponti
# 2         Matteo          De Ponti
# 3          Maria         Cuscianna
# 4           Luca        Malgioglio
#
# Spedizioni DataFrame:
#    id_ticket  id_spedizione           data_inserimento  \
# 0        NaN           1017 2018-11-28 11:45:15.460972
# 1        NaN           1735 2020-01-28 08:54:12.544856
# 2        NaN           2238 2021-03-10 12:36:04.938636
# 3     2756.0           1014 2018-11-27 11:47:56.164046
# 4     2824.0           1011 2018-11-26 09:18:26.634521
#
#                                           spedizione materiale  id_operatore  \
# 0                           ciao<br />ciao<br />ciao      None             6
# 1  spedire n. 1 display 10" Philips (scaricare pe...      None             7
# 2  Per mercoledì 17/03 predisporre n. 1 mini pc u...      None             7
# 3           testone<br />testoneee<br />testonissimo      None             6
# 4                                     ciaonneeeeeeee      None             6
#
#   operatore_nome operatore_cognome
# 0         Matteo          De Ponti
# 1          Laura              Cusi
# 2          Laura              Cusi
# 3         Matteo          De Ponti
# 4         Matteo          De Ponti

# %%
# Analyze data
analyze_ticket_data(ticket_df, rientri_df, spedizioni_df, materiale_clienti_df)
# Out:
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets['data_modifica'] = pd.to_datetime(closed_tickets['data_modifica'], errors='coerce')
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets['data_apertura'] = pd.to_datetime(closed_tickets['data_apertura'], errors='coerce')
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets.loc[:, 'data_chiusura'] = closed_tickets['data_modifica']  # Assuming 'data_modifica' is the closed date
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets.loc[:, 'resolution_time'] = (closed_tickets['data_chiusura'] - closed_tickets['data_apertura']).dt.total_seconds() / 3600
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets['month_year'] = closed_tickets['data_chiusura'].dt.to_period('M')
# c:\Users\pinky\OneDrive\Documents\GitHub\w64app\src\dataProcess\visualize_data.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_tickets['month_year'] = closed_tickets['data_chiusura'].dt.to_period('M')  # Ensure this is added
# ['Maria' 'Federico' 'Matteo' 'Laura' None 'Davide' 'Alberto' 'Fabio'
#  'Luca' 'Donatella' 'Geremia' 'Alessio' 'Manolo' 'Dario' 'Alessandra'
#  'Riccardo' 'Roberto' 'Elena' 'Kristo' 'Andrea' 'Donato' 'Stefano'
#  'Fatima' 'Gualtiero']
#
# Average Ticket Resolution Time per Operator:
#    operatore_nome  resolution_time
# 0         Alberto      3314.137197
# 1      Alessandra      2780.074903
# 2         Alessio       975.374859
# 3          Andrea      1552.737466
# 4           Dario       759.534721
# 5          Davide      1698.085920
# 6       Donatella      2771.219857
# 7          Donato       486.255382
# 8           Elena       366.435822
# 9           Fabio       696.293910
# 10         Fatima      1086.664581
# 11       Federico      1149.985150
# 12        Geremia       344.172620
# 13      Gualtiero         0.053909
# 14         Kristo         8.549546
# 15          Laura       738.737163
# 16           Luca       804.224995
# 17         Manolo       367.824551
# 18          Maria       223.322347
# 19         Matteo      1414.559080
# 20       Riccardo       622.884958
# 21        Roberto      5056.170609
# 22        Stefano         0.127365
#
# Monthly Closed Tickets per Operator:
#     operatore_nome month_year  ticket_count
# 0          Alberto    2016-07             1
# 1          Alberto    2017-08             1
# 2          Alberto    2019-05             1
# 3          Alberto    2021-06             1
# 4          Alberto    2021-09             1
# ..             ...        ...           ...
# 428       Riccardo    2024-10            13
# 429       Riccardo    2024-11            11
# 430       Riccardo    2024-12             4
# 431        Roberto    2021-06             1
# 432        Stefano    2022-05             1
#
# [433 rows x 3 columns]
# Total Ticket Summary by Status:
#                  id_stato  ticket_count
# 0                APERTURA           149
# 1             ASSISTENZA2           119
# 2          ATTESA CLIENTE           415
# 3      ATTESA COMMERCIALE           108
# 4       ATTESA INTERVENTO            70
# 5        ATTESA MATERIALE           172
# 6         ATTESA SVILUPPO            70
# 7                CHIUSURA         10645
# 8   INTERVENTO COMPLETATO           204
# 9                     PIC            51
# 10             RICHIAMARE             8
# 11                SOSPESO            98
# Spedizioni Summary by Client and Material:
#                      cliente_nome                  materiale  spedizioni_count
# 0                      GPI S.p.A.                    Mini pc                36
# 1                      GPI S.p.A.             Mini pc server                23
# 2                      GPI S.p.A.                    Monitor                48
# 3                      GPI S.p.A.  Monitor Android con patch                11
# 4                      GPI S.p.A.                  Stampante               106
# 5                      GPI S.p.A.                 all in one                 8
# 6                      GPI S.p.A.                      altro               143
# 7                      GPI S.p.A.                     tablet                 6
# 8   MALPENSA LOGISTICA EUROPA SPA                  Stampante                 3
# 9   MALPENSA LOGISTICA EUROPA SPA                 all in one                 1
# 10  MALPENSA LOGISTICA EUROPA SPA                      altro                 3

# %%
# Forecast ticket counts for the next 12 weeks
forecasted_tickets = forecast_tickets(ticket_df, weeks_to_forecast=12)
# Out:
# 07:43:59 - cmdstanpy - INFO - Chain [1] start processing
# 07:43:59 - cmdstanpy - INFO - Chain [1] done processing
# Forecasted Weeks and Ticket Counts:
#              forecast
# ds
# 2024-12-15  22.397939
# 2024-12-22  19.313111
# 2024-12-29  16.534992
# 2025-01-05  16.891247
# 2025-01-12  21.355391
# 2025-01-19  27.206075
# 2025-01-26  30.167937
# 2025-02-02  28.562271
# 2025-02-09  24.874505
# 2025-02-16  22.946383
# 2025-02-23  24.014097
# 2025-03-02  26.006935
